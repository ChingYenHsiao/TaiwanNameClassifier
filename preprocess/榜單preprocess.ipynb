# %%
#-*- coding: utf-8 -*-
import os
import editdistance
import sys
import linecache

# %%
from mylib.PrintException  import PrintException
from mylib.is_chinese import is_chinese
from mylib.is_number import is_number

# %%
#-*- coding: utf-8 -*-
import operator

# data = open("./univeristyName/1970/1970.txt").read() 
# if data[:3] == codecs.BOM_UTF8: 
#     data = data[3:] 
#     print (data.decode("utf-8"))
F = open('./univeristyName/1990-2000/2000.txt', 'r',encoding = 'utf-8')
character_dic = {}
Non_chinese_dic = {}
c = 0
for line in F.readlines(): 
    for character in line:
        
        if is_chinese(character)==True:
            if (character in character_dic):
                character_dic[character]+=1
            else:
                character_dic[character] = 1 
        else:
            if (character in Non_chinese_dic):
                Non_chinese_dic[character]+=1
            else:
                Non_chinese_dic[character] = 1

# %%
sorted_character_dic = sorted(character_dic.items(), key=operator.itemgetter(1))
sorted_character_dic.reverse()

# %%
sorted_character_dic[:100]
# Out:
# [('陳', 8060),
#  ('林', 7537),
#  ('李', 4453),
#  ('張', 4406),
#  ('黃', 4399),
#  ('王', 3659),
#  ('吳', 3101),
#  ('怡', 3013),
#  ('文', 2687),
#  ('雅', 2254),
#  ('劉', 2120),
#  ('婷', 2021),
#  ('許', 1976),
#  ('君', 1926),
#  ('佳', 1572),
#  ('明', 1540),
#  ('如', 1538),
#  ('志', 1503),
#  ('蔡', 1474),
#  ('洪', 1456),
#  ('欣', 1394),
#  ('謝', 1365),
#  ('宏', 1347),
#  ('楊', 1310),
#  ('芳', 1244),
#  ('家', 1208),
#  ('惠', 1207),
#  ('玲', 1197),
#  ('邱', 1188),
#  ('郭', 1186),
#  ('鄭', 1115),
#  ('傑', 1098),
#  ('宜', 1069),
#  ('俊', 1066),
#  ('曾', 1028),
#  ('淑', 1001),
#  ('彥', 991),
#  ('徐', 986),
#  ('蘇', 947),
#  ('雯', 938),
#  ('玉', 903),
#  ('銘', 837),
#  ('江', 829),
#  ('育', 815),
#  ('秀', 765),
#  ('芬', 757),
#  ('呂', 754),
#  ('政', 734),
#  ('柏', 729),
#  ('仁', 715),
#  ('孟', 712),
#  ('何', 712),
#  ('宇', 705),
#  ('宗', 698),
#  ('周', 685),
#  ('一', 681),
#  ('方', 674),
#  ('伶', 666),
#  ('盈', 662),
#  ('立', 661),
#  ('凱', 660),
#  ('建', 654),
#  ('簡', 653),
#  ('安', 652),
# ...

# %%
Non_chinese_dic
# Out:
# {'\t': 95,
#  '\n': 80599,
#  ' ': 17027,
#  '!': 132,
#  '"': 156,
#  '#': 765,
#  '%': 167,
#  '&': 642,
#  "'": 1445,
#  '(': 370,
#  ')': 377,
#  '*': 33,
#  '+': 89,
#  ',': 403,
#  '-': 2382,
#  '.': 1586,
#  '/': 191,
#  '0': 1189,
#  '1': 4052,
#  '2': 514,
#  '3': 1326,
#  '4': 996,
#  '5': 1454,
#  '6': 390,
#  '7': 568,
#  '8': 721,
#  '9': 476,
#  ':': 742,
#  ';': 192,
#  '=': 6,
#  '?': 7428,
#  '@': 92,
#  'A': 1,
#  'I': 2001,
#  'V': 424,
#  'X': 409,
#  '[': 14,
#  '\\': 247,
#  ']': 25,
#  '^': 5614,
#  'x': 1,
#  '|': 600,
#  '~': 75,
#  '±': 132,
#  '—': 322,
#  '‘': 239,
#  '’': 137,
#  '“': 127,
#  '”': 192,
#  '…': 18,
#  '─': 16,
#  '、': 278,
#  '。': 162,
#  '〃': 6,
#  '〈': 5,
#  '〉': 1,
#  '《': 317,
#  '》': 100,
#  '「': 61,
#  '」': 164,
#  '『': 28,
#  '』': 54,
#  '【': 37,
#  '】': 14,
#  '〒': 58,
#  '〔': 19,
#  '〕': 26,
#  '！': 612,
#  '％': 139,
#  '（': 15,
#  '）': 5,
#  '，': 2398,
#  '：': 1473,
#  '；': 894,
#  '？': 1480,
#  '～': 13}

# %%
def findSimName(name):
    for c in name:
        if c in Simchar_list:
            return True
    return False
Simchar_list = ['尧', '颉', '饰', '锴', '严', '树', '骅', '沣', '荣', '镪', '钳', '汉', '咸', '载', '遥', '乔', '执', '宁', '赖', '辉', '诶', '寿', '傧', '军', '芦', '亿', '鸟', '丰', '笃', '国', '号', '铮', '粝', '宾', '宝', '环', '钏', '参', '郧', '纪', '玺', '鲪', '桥', '艳', '铜', '创', '绍', '纱', '众', '鸣', '问', '阎', '语', '瑶', '纤', '却', '亚', '颖', '绰', '宽', '违', '亲', '简', '掴', '点', '鹩', '门', '赠', '满', '状', '滨', '卢', '制', '槟', '悯', '涢', '应', '织', '异', '愍', '贞', '跖', '隽', '润', '涌', '茏', '缘', '悦', '诘', '绅', '羡', '帏', '迁', '猫', '怀', '龚', '纹', '泪', '径', '坟', '靓', '错', '鉴', '绣', '叶', '翘', '谢', '劲', '实', '苇', '札', '婵', '俪', '艺', '礼', '独', '忏', '鲁', '岚', '愿', '诗', '贵', '栊', '驯', '协', '镜', '孙', '贺', '珲', '飏', '佣', '书', '烨', '赈', '梦', '凤', '权', '贻', '顿', '龙', '净', '战', '继', '刮', '娅', '韦', '苎', '财', '峥', '离', '颋', '远', '听', '谣', '浅', '肃', '坏', '虬', '陆', '纺', '绯', '绨', '启', '莼', '畅', '蓝', '帻', '胜', '炜', '择', '责', '译', '键', '钢', '营', '觉', '价', '娴', '链', '粮', '嫔', '鹏', '缌', '镌', '圣', '伟', '锨', '儿', '炽', '丽', '谌', '镱', '莱', '钛', '献', '迩', '渊', '谕', '荩', '岗', '嫒', '鸿', '禄', '恺', '腾', '玮', '齐', '韩', '马', '奥', '吴', '谊', '衔', '滥', '厂', '帅', '侬', '郓', '锜', '赢', '显', '袄', '识', '纭', '历', '轩', '锦', '鹰', '广', '浔', '钎', '优', '缮', '泺', '挥', '蒋', '几', '进', '坚', '颢', '内', '园', '罗', '弹', '荧', '绚', '轲', '晖', '粤', '恋', '鹤', '萧', '体', '茔', '济', '备', '态', '风', '钲', '姗', '荟', '忆', '频', '组', '邝', '谦', '赏', '构', '详', '伙', '彦', '晕', '赜', '绗', '届', '霉', '暧', '颐', '积', '诺', '檐', '画', '邻', '沵', '镗', '莳', '联', '释', '双', '锌', '铨', '则', '谁', '绫', '侠', '宪', '颜', '许', '郑', '娇', '乐', '匀', '与', '见', '凯', '维', '铧', '仪', '闿', '势', '湾', '吕', '荆', '闻', '鹂', '寻', '冻', '锑', '铟', '泷', '灯', '兰', '纳', '师', '蕴', '兹', '将', '强', '绮', '词', '襁', '锋', '肠', '样', '纸', '讳', '议', '戬', '泽', '珑', '称', '骏', '飘', '凛', '绥', '刘', '镁', '恳', '顺', '钇', '踊', '么', '并', '动', '钧', '机', '钰', '锝', '贪', '锶', '镒', '顶', '圆', '颂', '铃', '迈', '钟', '樱', '时', '阚', '镔', '长', '沩', '缇', '逊', '东', '镓', '标', '鳗', '庆', '训', '达', '镛', '奖', '铉', '娱', '万', '欧', '冯', '莅', '晋', '声', '铠', '萤', '蔷', '莲', '缠', '冁', '扬', '跞', '幂', '诰', '锵', '叙', '会', '经', '琼', '晓', '祯', '驰', '飞', '贰', '为', '绿', '焕', '综', '爱', '鲜', '弪', '袯', '扎', '誉', '闳', '濑', '义', '领', '镅', '纬', '尔', '灏', '谜', '谚', '贤', '冲', '萦', '硕', '闵', '灵', '迹', '鹃', '洁', '种', '桦', '响', '纠', '咝', '秾', '帼', '咔', '兴', '炀', '苏', '复', '蒙', '诚', '没', '篱', '侨', '卺', '嵘', '镫', '观', '捞', '银', '渐', '栎', '涛', '玛', '赞', '颀', '资', '欢', '铿', '闪', '忧', '祎', '缋', '开', '赐', '钊', '咙', '贾', '缜', '稳', '柜', '凭', '旸', '剑', '红', '纯', '只', '晒', '钿', '静', '栋', '笔', '荭', '华', '发', '证', '洒', '贝', '骐', '烁', '戏', '陈', '聪', '学', '缙', '后', '来', '轶', '瑷', '汇', '倾', '噜', '滢', '潍', '纶', '杨', '泶', '枨', '浓', '过', '阳', '镇', '萝', '张', '运', '况', '纾', '铷', '视', '扑', '温', '桢', '摇', '琏', '诒', '钦', '结', '丝', '约', '颍', '刚', '壮', '网', '岭', '勋', '浈', '励', '荐', '业', '临', '争', '给', '邓', '记', '竞', '虫', '铍', '尽', '叹', '铭', '连', '传', '枫', '锐', '伦', '涡', '表', '踪', '龄', '钞', '个', '绘', '卫', '咨', '蓥', '总', '别']

# %%
#OCR 出來的榜單資料
#1958-2000年榜單　37份（缺6年）　1988　1989 1990　1991　1992　1994　
#1940-1982　出生
#87歲-35歲
count = 0
Path ='./univeristyName2/'
Path2 = './univeristyName3/'
year_character_dic = {}
Missing_year_list = ['1988','1989','1990','1991','1992','1994']
for root, dirs, fileNames in os.walk(Path):
    if fileNames ==[]:
        continue
    for fileName in fileNames:
        try:
            with open(root+"/"+fileName ,'r',encoding = 'utf-8') as F:
                print(fileName)
                character_dic = {}
                #一行一行讀
                

                with open(Path2+fileName ,'r',encoding = 'utf-8') as W:
                    for line in F.readlines():
                        #丟掉大學名稱
                        Drop_line = False
                        #1整行丟
#                         for un in  drop_name:
#                             if (editdistance.eval(line,un)<=2):
#                                 print(line)
#                                 Drop_line = True
#                                 break
#                         if Drop_line !=True:
#                             W.write(line)
                        #2丟掉
                        length = 0
                        sp = line.split(' ')
                        for s in sp:
                            for dr in  drop_name:
                            #for n in number_list:
                               # if(editdistance.eval(line[:len(dr)],a)<=1 and line[1]=='名'):

    #                             if (editdistance.eval(line[:len(dr)],dr)<=4 ):
    #                                 #if  line[0] in number_list or  line[1] in number_list:
    #                                 #if len(line) == 3:
    #                                 #print(line)
    #                                     Drop_line = True
    #                                     if'名' in line:
    #                                         length = line.index('名')+1
    #                                     elif '系' in line:
    #                                         length = line.index('系')+1
    #                                     else:
    #                                         length = len(dr)
    #                                     count+=(length)
    #                                     break

    #                         if('名' in line and '學系' in line and len(line)<30):
    #                             #print (line[:line.index('名')+1])
    #                             count+=len(line[:line.index('名')+1])
    #                             Drop_line = True
    #                             length = line.index('名')+1


                                if (editdistance.eval(line[:len(dr)],dr)<=5):
                                    length = len(dr)
                                    count+=(length)
                                    Drop_line = True
                                    break
                                #if len(line)<60:

#                                 for n in number_list:
#                                     for nn in number_list:
#                                         target = n+'十'+nn+'名'  
#                                         if target in line:
#                                             #print (line[:line.index('名')+1])
#                                             Drop_line = True
#                                             length = line.index('名')+1
#                                             count+=length
#                                             break

#                                     if Drop_line == True:
#                                         break

                            if Drop_line !=True:
                                #pass
                                #print ("Write:",s)
                                W.write(s)
                            else:
                                print("Drop:",s)
                                break
                                #print("Write:",line[length:])                                
#                                 print("Drop:",line[:length])
#                                 print("Write:",line[length:])
                                #W.write(line[length:])

                    #print(line)
#                     for character in line:
#                         if is_chinese(character)==True and findSimName(character)==False:
#                             if (character in character_dic):
#                                 character_dic[character]+=1
#                             else:
#                                 character_dic[character] = 1 
#                 year_character_dic[fileName[:4]] = character_dic
            
        except Exception as e:
            print (e)
            print (fileName)
            PrintException() 
            
print('Drop:',count,'字')
# Out:
# 1983.txt
# Drop: 丁.五0
#
# Drop: 統計一
#
# 1966.txt
# 1996.txt
# Drop: ^%4-一三名
#
# Drop: 中國音樂學樂0名
#
# Drop: 一興》一1五名3哲黃番江％“
#
# Drop: ^9^?五0名
#
# Drop: 島科59一一名
#
# Drop: 公應期數學糸三五名
#
# Drop: 54與終四五名
#
# Drop: 6物理學系七
#
# Drop: 6工雌映五I名
#
# Drop: 公1111五名I？
#
# Drop: :學龍|一二名
#
# Drop: ?圓藝學系七
#
# 1987.txt
# Drop: ?歷史I四五名呵冀詔郁蜞許彬文黃致閏曾文髏陳佳穎
#
# Drop: 6人類學秦二五名
#
# Drop: 〈財務金融學於五0^
#
# Drop: 舍腎學杗四03
#
# Drop: 〈財稅學系五0？?
#
# Drop: 八舍針學系五0？
#
# Drop: 〈中田文擎系五0^滴簿旺劉泡芙陳姮良張孟怡陳明招劉新4屬禹
#
# Drop: ?外菌語文學系四^？只其昌林資英陳翠泖枵3美林銘祥黃政孰林！
#
# Drop: ?中困文學臬四五名曲言台鎗國禪何正光14素療陳嘵玲歐皤瑜劉鼴君裎1吳乃嫺幹溝窣李光世劉亦?駱芳彬拖寬文蘇丞偉莫詒文強秀邙廖勝賢楊玲！李怡寬興宋莉葉定國林靜慧蔡昭蓉蔡4^1陳^&捫3吳怡明王幸援朱淑梅呂一^許測佳胡靜君
#
# Drop: 〈醱史學杗五0^1邱金佑張興分周寧琳黃邡芬張世瑛趙如418^簡宇宏潘圉??幸足林^^林瑞3廚思坤?志祥曾俊炸旺雅蕓
#
# Drop: 〈法律學系法學組六0一陳雅莉翁嘵玲孔菊比徐一^陳雅琴陸灼華謝碧連康淑氣劉雅如巴秀姻鄭淑婉，。I一；^捕榮林厚沖李魁&羅嘉松範/吶町志益周—馬桂玲
#
# Drop: 財稅學杗六0名
#
# Drop: #計學杗六。名
#
# Drop: 〈中留文學系四0^
#
# Drop: 蒹管理學杗四0名
#
# Drop: 〈資訊泠即學系四0^
#
# Drop: 理學杗五0：
#
# Drop: ^關術學系─0、^釗呂榮鱺^7^林足秋
#
# Drop: 乙&句學杗二五名
#
# ...

# %%
drop_name = ['地理學糸(氣凍組〕一十1名】','一中國文學系二卜四名','【屢工穭學系二十九名】','旅館與餐飲管理學系 五七名','【土木工?學糸一^八名】','公共政策與管理學系四五名','湖丁1^與管理學系','大氣科學系 ?0名']#,'私立輔仁大學']
#drop_name = ['拾名']#,'OO名',''XX系OO名'']
#drop_name = ['XX學系(男)','XX學系(女)','音樂學系-大提琴二名','XX學系','政治學系六十二名']
#drop_name = ['核子工稃學系四十人各','土木工#學系伍拾阼名','1台灣省立成功大學','外國冶文學組三十八名','中闕文學糸陸拾肆名','哲學糸四十八名 ']
#drop_name = ['(地埋組)|十，二名','化學系三十三義','化學系化舉組四八名','化學工程學系九九名','育學系《自賢男二五名','醫學系自賢|||五名','程學系(第二部)六九名',
#             '商學系國際貿務組：三三名','妒學系?押統#組七十工一名','農#工程學系(廉^械組)1十五名','養學系食品科學組五五名','藥學系I百七屮二名','?化學工程學系|I九名']
#drop_name = ['縻縻名']
#drop_name = ['5立成功大學—I','入理舉院\^','機械工程學豕','〈日本鑷文學系五0名']
#drop_name = ['叫心斑？:糸一十I名】','【洙?糸(法學誡)五十六名】','獨1保二十一名一','【森林崇改二十名】']
#drop_name = ['一十二名']
drop_name = ['國立清華大學','台灣省立海洋學院','私立中國文化學院','物埋學系二十九名','公共行政學系五0名','應用外國語文學系三一名','企業管理畢系一九二名']
drop_name = ['法律學糸法學組七0名','人類學杗一五名','柬力語文中矣俄語組','中圃文學系七0名','財務金融學系四0名','資訊笄理學系五0^','外閾語文學系三五名','統計學杗五0名']
# 化學糸
# 中國文學系
# 私立中國文化學院
# 政治學系(政治理論組：二十名 
# 政治學系(政治理論組：二十名 
# 國立中興
#      私立台北醫學院

#      困立成功
# 統計學系
#      台灣省立海洋學院
# 大氣物理學系?
# 法商學院法涕
#      私立靜宜女子文理學院
#      企業管理學系

number_list = ['一','二','三','四','五','六','七','八','九','十','1','0','2','3','4','5','6','7','8','9']
#OCR_addtional = ['國','立','大','學','系','一','二','三','四','五','六','七','八','九','十','名','退','伍','軍','人']

# %%
university_name = ['法學院','農學院','商學院','理學院','國立台灣大學','國立清華大學','國立交通大學','國立政治大學','私立中原理工學院','省立高雄師範學院','台灣省立師範大學',
                   '私立中國文化學院','私立大同工學院','靜宜女子文理學院','私立逢甲工商學院','國立師範大學','中央大學理學院','私立東海大學',
                  '私立輔仁大學','私立東海大學','私立中國醫藥學院','大同專科學校','私立淡江文理學院','農業專科學校','中山牙醫學校',
                  '東吳大學法學院','靜宜女子學院','大同工業專科學院','世界新聞專科學校','銘傳女子學校','台灣藝術專科學校','國立台灣師範大學',
                  '東吳大學']

# %%
經濟學系
政治學系公共行政組四
政治學系塞際囑係組0
-系政治理論組四
法律學系財經法組五^-?
法律學系司法組五0名 
法律學系法學組五0名 
戲劇學系(女)I五名 
戲劇學系(男二六名 
日本語文學系四七名
人類學系三三名 
躕害資訊學系四六名
哲學系六0名 
財務金融學系
際企業鼙杲
教育學系八0名
社會教育學系斷颺學組二五名
社龕教育學系社魯工作組二五
社會?育學系圓窖資訊學軺二
敦育V理與轆導學系四0名
特殊教育學系(自費)一
特殊教育學系《公費》七名
英語學系三0名 卜
音樂學系-管樂二名
音樂學系-理禱作?二名
瞀樂學系-中蘭傳統樂器I名

美術學系三四名 
音樂學系-鋼琴I四名
?樂學系-聲樂一名
醬樂學系-弦樂九名
中國文學系五二名
企窠資理學系四三名
# Out:
#   File "<ipython-input-1-af3d0b2f192d>", line 5
#     法律學系財經法組五^-?
#                ^
# SyntaxError: invalid syntax

# %%
Path ='raw_list_1994-2012'
skip_list 
#skip_list = ['1995','2007','2006','2005','1998','2000','1997','1999','1994','2003','1996','2002','2012','2004','2001','2011','2008']
later_list = ['1995']
for root, dirs, fileNames in os.walk(Path):
    if fileNames ==[]:
        continue
    for fileName in fileNames:
        if fileName in skip_list:
            continue
        try:
            with open(root+"/"+fileName ,'r',encoding = 'utf-8') as F:
                
                #一行一行讀
                print(fileName)
                count = 0
                w = open('./87/'+fileName,'w')
                
                for line in F.readlines():
                    tmp = line.replace("\n",'').split(" ")
                    #tmp = line.replace("\n",'').split("	")
                    number = False
                    for s in tmp:
                        print(s)
                        if()
#                         if len(s)>1:
#                             ss = s.split("　")
#                             if is_number(ss[0] ) and len(ss)>1:
#                                 print (ss[1])
#                                 w.write(ss[1]+'\n')
#                                 count+=1
                                
                        #1995
#                        if len(s)>7 and is_number(s[5]):
#                             index = 0
#                             for c in s:
#                                 if(is_number(c)):
#                                     index+=1
#                                 else:
#                                     break
#                             #print(s[index:])
    
#                             if(index!=len(s)):
#                                 print(s[index:])
#                                 #print(s)
#                                 w.write(s[index:]+'\n')
#                                 count+=1
                            
                        #2007
#                         if len(s)>1 and s[0]=='(' and ')' in s:
#                             print( s[ s.index(')')+1:])
#                             w.write( s[ s.index(')')+1:]+'\n')
#                             count+=1
                        #2006
#                         if len(s)>1:
#                             if(number):
#                                 print(s)
#                                 number = False
#                                 count+=1
#                                 #w.write(s+'\n')
#                             if is_number(s[0]):
#                                 number = True
#                             #print(s)

                        #if(len(s)>1 and is_number(s[0]) and '大學' not in s and '類組' not in s and '學院' not in s and '*' not in s):
                            #print(s)
                            #print(s[6:])
                            #w.write(s[7:]+'\n')

#                             index = 0
#                             for c in s:
#                                 if(is_number(c)):
#                                     index+=1
#                                 else:
#                                     break
                            #print(s[index:])
    
#                             if(index!=len(s)):
#                                 #print(s[index+1:])
#                                 #print(s)
#                                 w.write(s[index:]+'\n')
#                                 count+=1
                            
#                         if '　' in s and is_number(s[0]):
#                             #print(s.split('　')[1]) 
#                             if( len(s.split('　')[1])>1):
#                                 count+=1
#                                 print(s.split('　')[1]) 
                                #w.write(s.split('　')[1]+"\n")
                print(count)

        except Exception as e:
            print (e)
            print (fileName)
            PrintException()                     

            break
# Out:
# 2005
# 各科系錄取名單
#
# 華視全球資訊網　大學聯招查榜
#
# 國立臺灣大學
#
#
#
#
#
#
#
# 　中國文學系
# 最低加權錄取總分	388.50
# 22001312　施璇蓉
# 22009925　夏其心
# 22013614　孫暄晴
# 22019437　郭哲佑
# 22021832　鄭　文
# 22023314　呂相璽
# 22023425　鄭雅云
# 22023701　劉芯妤
# 22023818　李竺頤
# 22023830　林美汎
# 22024939　周昀萱
# 22025306　陳昕平
# 22026027　嚴倢妤
# 22027037　王若馨
# 22035013　蔡宗達
# 22041525　王星博
# 22042315　張純昌
# 22047213　洪道安
# 22051441　吳品萱
# 22055715　謝宛諭
# 22060834　邱璿任
# 22061213　陳鈞昂
# 22073117　羅詩怡
# 22078716　張俊翰
# 22082109　洪世容
# 22083301　許堯婷
# 22083525　黃繼葵
# 22083608　陳昭安
# 22083942　蔣闊宇
# 22090303　林　佳
# 22090401　蔡宛儒
# 22098817　李威寰
# 22100318　吳佩熏
# 22104122　李映霖
# 22115642　張雅鈞
# 22119339　陳昱
# 22120241　陳緒民
# 22123005　張馥如
# 22132006　賴以純
# 23021030　鄭伊玲
#
#
#
# (C)
# 2005
# CTS.All
# Rights
# Reserved
# Designed
# by
# CTS
# WebCrew.
# Best
# View
# 1024*768
#
# 各科系錄取名單
#
# 華視全球資訊網　大學聯招查榜
#
# 國立臺灣大學
#
#
#
#
#
#
#
# 　外國語文學系
# 最低加權錄取總分	385.52
# 22000327　陳芳誼
# 22001313　陳彥霖
# 22001527　陳　瑋
# 22001834　陳韋翰
# 22013110　林書歆
# 22016916　李維真
# 22018722　廖大賢
# 22019141　王聖富
# ...

# %%
import os

special_list = ['','','','','','','','','','','','','','','','','','','','','','','','',''
               ,'','','','','','','','','','','','','','','','','','','','','','','','',
               '','','','','','','','','','','','','','','','','','','','','','','','','',
               '','','','','','','','','',')','&','^','#','$','@','%','-','','','','','','','','',
               '','','','','','','','','','','','','','','','','','','','','','','','',
               '','','','','','','','','','','','','','','','','','','','','','','','',''
               ,'','','','','','','','','','','','','','','','','','','','','','']

c = 0
Path = '1994-2012_2'
for root, dirs, fileNames in os.walk(Path):
    if fileNames ==[]:
        continue
    w = open("C_1994-2012_2/Total_1994-2012.csv" ,'w')
    w.write('year,name\n')
    for fileName in fileNames:
        try:
            with open(root+"/"+fileName ,'r',encoding = 'utf-8') as F:
                #一行一行讀
                
                for line in F.readlines():
                    name = line.replace("\n",'')
                    #if(len(name)==1 or 
#                     if is_chinese(name)==False:
#                         tmp_list = []
#                         for n in name:
#                             tmp_list.append(n)
#                         if len(list(set(tmp_list).intersection(special_list)))==0:
#                             c+=1
#                             print(c,fileName,name)
                    tmp_list = []
                    for n in name:
                        tmp_list.append(n)
                    if len(name)!=1 and len(list(set(tmp_list).intersection(special_list)))==0:
                        w.write(fileName+','+name+'\n')
        except Exception as e:
            print (e)
            print (fileName)
            PrintException()

# %%
from mylib import is_chinese

# %%
from mylib.is_chinese import is_chinese

# %%
from mylib.PrintException import  PrintException

# %%
is_chinese("a")
# Out:
# False

# %%
from mylib.is_chinese

# %%
mylib

# %%
mylib.is_chinese.is_chinese("a")
# Out:
# False

# %%
# 判斷一個unicode是否為中文
#http://www.wangmingkuo.com/python/python%E4%B8%AD%E5%88%A4%E6%96%AD%E5%AD%97%E7%AC%A6%E6%98%AF%E5%90%A6%E6%98%AF%E6%B1%89%E5%AD%97%E3%80%81%E5%AD%97%E6%AF%8D%E4%BB%A5%E5%8F%8A%E6%95%B0%E5%AD%97/
def is_chinese(string): 
    #print (string)
    try:
        for uchar in string:
            if '\u4e00' <= uchar<='\u9fff':
                pass
            else:
                return False
        return True
    except Exception as e:
            print (e)
            print (string)

# %%
#發現有人重複上不同學校,要用准考證號碼來看 重篩 

Path ='raw_list_1994-2012'
Finished_list = ['1995','1996','1997','1998','1999','2000','2001','2002','2003','2004','2005','2006','2007','2008','2010','2011','2012']
#skip_list = ['1995','2007','2006','2005','1998','2000','1997','1999','1994','2003','1996','2002','2012','2004','2001','2011','2008']
skip_list = []
for root, dirs, fileNames in os.walk(Path):
    if fileNames ==[]:
        continue
    for fileName in fileNames:
        if fileName in Finished_list or fileName in skip_list: 
            continue
        try:
            with open(root+"/"+fileName ,'r',encoding = 'utf-8') as F:
                
                #一行一行讀
                print(fileName)
                count = 0
                w = open('./87/'+fileName,'w')
                name_dic = {}
                for line in F.readlines():
                    #2005
#                     tmp = line.replace("\n",'').split(" ")
#                     #tmp = line.replace("\n",'').split("	")
#                     number = False
#                     for s in tmp:
#                         if is_number(s[:8]) and len(s)>8:
#                             #print(s)
#                             #print(s[:8]+'=='+s[9:])
#                             Test_number = s[:8]
#                             Name = s[9:].replace('　','')
#                             if Test_number not in name_dic:
#                                 name_dic[Test_number ] = Name
#                             else:
#                                 print('重複計算',Name)
#                                 count+=1
                    
                    #tmp = line.replace("\n",'').replace('    ','　  ').split('　  ')
                    #tmp = line.replace("\n",'').replace(' 	','*').replace('	','').split('*')
                    tmp = line.replace("\n",'').split('    ')
                    #7 1998.2000
                    #6 1997
                    #8 2012 2011
                    Number_length = 6
                    
                    name_flag = False
                    Test_number = ''
                    for s in tmp:  
                        #print(s)
                        #2006
#                         if(name_flag):
#                             Name = s
#                             if Test_number not in name_dic:
#                                 name_dic[Test_number ] = Name
#                             else:
#                                 print('重複計算',Name)
#                                 count+=1
                                
#                             name_flag =False
#                         if(check_how_much_number(s,Number_length)):
#                             name_flag = True
#                             Test_number = s

                        if check_how_much_number(s,Number_length) and len(s)>Number_length:
                            
                            if(len(s)>14):
                                
                                Test_number1 = s[:Number_length]
                                Name1 = s[Number_length:Number_length+4]
                                Test_number2 = s[Number_length+6:Number_length*2+6]
                                Name2 = s[Number_length*2+6:]
                                #print(Test_number1+'-'+Name1)
                                #print(Test_number2+'-'+Name2)
                                
                                if Test_number1 not in name_dic:
                                    name_dic[Test_number1 ] = Name1
                                else:
                                    print('重複計算',Name1)
                                    count+=1        
                                    
                                if Test_number2 not in name_dic:
                                    name_dic[Test_number2 ] = Name2
                                else:
                                    print('重複計算',Name2)
                                    count+=1       
                            else:
                                Test_number = s[:Number_length]
                                Name = s[Number_length:].replace('  ','')
                                #print(Test_number+'-'+Name)
                                if(len(Name)==1):
                                    print(s)
                                if Test_number not in name_dic:
                                    name_dic[Test_number ] = Name
                                else:
                                    print(Test_number,'重複計算',name_dic[Test_number],Name)
                                    
                                    count+=1
#                         else:
#                             print(s)
                                
                print(count)
                print(len(name_dic))
                
                c=0
                for n in name_dic:
                    c+=1
                    #print('No.',c,n,name_dic[n])
                    w.write(name_dic[n].replace(' ','').replace('　','')+'\n')
                break
        
        except Exception as e:
            print (e)
            print (fileName)
            PrintException()                     

            break
# Out:
# 1994
# 0
# 55236

# %%
def check_how_much_number(s,n):
    count=0
    for c in s:
        if c>='0' and c<='9':
            count+=1
    if count == n:
        return True
    else:
        return False

# %%
r = open('./master/chang_gung/102-master')
m_list = []
for line in r.readlines():
    tmp = line.replace('\n','')
    if len(tmp)>1:
      m_list.append(tmp)

# %%
print(len(m_list))
# Out:
# 2669

# %%
r = open('./else/北一女/1970')
tmp_list = []
for line in r.readlines():
#     tmp = line.replace('\n','')
#     if len(tmp)>1:
#       m_list.append(tmp)  
    if len(line)>10:
        tmp = line.split(' ')
        if(len(tmp)>1):
            print(tmp[2])
            if(len(tmp)>5):
                print(tmp[5])
                if(len(tmp)>7):
                    print(tmp[8])
#             if len(tmp[1])!=1:
#                 print(tmp[1])
#             else:
#                 print(tmp[1]+tmp[2])
        
#         if is_number(tmp[0]):
#             print(tmp[1])
#         else:
# #             print(tmp[0].replace('　	',''))
#         if( tmp[1]+tmp[2] not in tmp_list):
#                 tmp_list.append(tmp[1]+tmp[2])
# Out:
# 楊承峰
# 白昀庭
# 楊宗翰
# 林郁雯
# 張博閔
# 陳沿靜
# 洪梵鐘
# 簡佑丞
# 廖廷域
# 蔡怡禎
# 王思懿
# 張國益
# 徐健軒
# 吳秉昀
# 胡佳瑩
# 柯驊耕
# 戴笠修
# 郭修華
# 袁學平
# 方定宇
# 朱佩璇
# 張崇恩
# 葉佳鴻
# 繆政穎
# 楊舒琪
# 吳宜靜
# 簡婉茹
# 莊茹驛
# 吳亭葶
# 廖翎娟
# 葉芷均
# 顏端緻
# 鄒宜馨
# 徐偉軒
# 李　耘
# 蔡佩君
# 林欣平
# 謝雅玉
# 魏同安
# 陳怡安
# 張馨勻
# 郭姿尓
# 林玟廷
# 陳沿靜
# 周暘景
# 翁至威
# 李王清
# 翁鼎禕
# 周宜澄
# 嚴　瀛
# 鄭雅竹
# 許雨嬙
# 夏逸庭
# 劉芷伊
# 張珈瑋
# 王新元
# 林亞嬙
# 黃文智
# 張天音
# 廖意欣
# 莊宜儒
# 林明緯
# 鄭𡜍婷
# 彭奎翰
# 高仲儀
# 劉庭亞
# 謝文匳
# 林芳儀
# 賴筱婷
# 張豪中
# 許雅婷
# 陳之云
# 賴佳伶
# 范　霖
# 蔡宜君
# 陳育慶
# 陳瑩儒
# 吳康渝
# 林尚甫
# 陳律晴
# 邱奕齊
# 林冠竹
# 盧美辰
# 陳雅倫
# 李琬琦
# 連娸蓉
# 陳彥名
# 劉彥伶
# 蔡培馨
# 江明遙
# 楊雯珺
# 葉芷均
# 張珮綺
# 吳芳伶
# 劉美君
# 鄭郁儒
# 林欣怡
# 林真園
# 陳怡君
# 陳力行
# 俞柏丞
# 蔡柏聖
# 戎　諒
# 陳柏誠
# 梁兆甫
# 李毓珊
# 楊家維
# 朱柏璁
# 孫育達
# 羅涵之
# 李俊鴻
# 蘇偉宏
# 林立祥
# 莊竣揚
# 柯　明
# 陳健樺
# 曾致堯
# 顏唯哲
# 李維哲
# 林聖哲
# 王任鋒
# 王介弘
# 柯伯勳
# 吳佳翰
# 歐正揚
# 吳永斌
# 王　辰
# 林玉婷
# 王暐翔
# 曾政憲
# 王明莊
# 陳冠綸
# 姜　傑
# 楊仲安
# 翁振勛
# 賴佳雲
# 徐文進
# 陳冠瑜
# 林科均
# 陳苡均
# 王　璿
# 盧怡頻
# 陳佑達
# 王維駿
# 羅湘瑩
# 洪啟程
# 江冠諠
# 張哲凱
# 黎家明
# 方俊詠
# 蘇煥評
# 劉家甫
# 周雅眉
# 謝宗錞
# 張家豪
# 王意華
# 林宏益
# 陳冠文
# 傅晟瑋
# 林世峻
# 蔡孟烜
# 胡靚妤
# 方建凱
# 鄭　𣾀
# 周煥焄
# 簡雅昕
# ...

# %%
r = open('./else/北一女/1978')
tmp_list = []
for line in r.readlines():
    if len(line)>10:
        tmp = line.split('	') 
        for n in tmp:
            if len(n)<=4 and len(n)>=2 and is_number(n)==False and  is_chinese(n):
                print(n)
# Out:
# 班級
# 中文姓名
# 居住地區
# 王苑芬
# 王寂岑
# 陳舜瑛
# 陳麗瑩
# 韓蕙明
# 鄭晳勻
# 林麗瑛
# 何垂欣
# 葉喩惠
# 魏如芳
# 曾小瑩
# 林如娥
# 黃明雲
# 蔡佳蓉
# 沙姍姍
# 姜小妹
# 江富美
# 范莎莉
# 魏玉琴
# 陳麗卿
# 陳曉梅
# 王曼珍
# 徐慧芝
# 郭明琪
# 楊金慧
# 樂宜修
# 莊樹華
# 陳淑姿
# 劉瓈惠
# 馮曉明
# 孫芳文
# 陳芬蘭
# 吳玫如
# 賴慧貞
# 高幼眉
# 蔣玉華
# 洪秀芳
# 陳蘭芬
# 吳碧珍
# 薛世文
# 開安平
# 林雪姿
# 梁慧薰
# 廖美琳
# 王文宜
# 鄭安齡
# 周婉蘋
# 蘇慧娟
# 陳肌伶
# 李玲純
# 諶家蘭
# 陳少燕
# 姚靜慧
# 陳孟蘭
# 張碧惠
# 游雪蘭
# 尤惠蕙
# 楊雪雲
# 王品玉
# 李明心
# 黃麗娟
# 章敏鈺
# 張素美
# 張妙治
# 朱健萍
# 游兆明
# 胡慧文
# 李貴敏
# 羅純美
# 劉玲琳
# 林雪芬
# 陳寶英
# 黃淑珠
# 林麗秋
# 李之倩
# 宋正玲
# 王愛蓮
# 朱筱蓉
# 陳碧峰
# 梁建菁
# 馬麗芳
# 潘白奇
# 陳玲慧
# 江淑如
# 陳婉容
# 侯怡泓
# 王秀槐
# 郭慧美
# 周美里
# 賀培真
# 蔡冠菁
# 劉淑芬
# 沈惠珠
# 葉淑瑩
# 黃慧宜
# 張紫媛
# 高婉玲
# 陳世忻
# 王珍珠
# 陳淑虹
# 林淑琴
# 陳雅美
# 柯淑華
# 陸雅平
# 潘月霞
# 董芳晶
# 鍾興健
# 詹惠珠
# 施芳玲
# 賴慧玲
# 謝靜芬
# 王婉如
# 王雅蕾
# 張美芳
# 袁淑真
# 蔣明惠
# 高佩瑛
# 王紫珩
# 林淑妃
# 孫幼玲
# 何月嬋
# 方希文
# 李麗香
# 蘇三芳
# 莊梅貞
# 李淑艾
# 普雪娥
# 倪志琳
# 林容穗
# 朱為華
# 嚴苔瑜
# 黃詩吟
# 劉小英
# 戴美華
# 吳俐慧
# 高志瑛
# 朱建萍
# 賴麗存
# 施文玲
# 魏琍琍
# 林麗萍
# 孫心怡
# 張瑞娟
# 林錦華
# 楊柳明
# 溫善惠
# 鄒淑琪
# 張淑貞
# 周毓文
# 張淑菁
# 葉嶽雲
# 趙秀貞
# 林秀美
# 黃景慧
# 林翠蘭
# 陳岸亭
# 邵美苓
# 陳文淑
# 黃玉鈴
# 鍾婉珊
# 任明玥
# 王仲蘭
# 楊蕙華
# ...
